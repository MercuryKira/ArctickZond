# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
# from ydata_profiling import ProfileReport
import numpy as np
import sqlite3

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("sputnik_sd_06.07.2024_new.sqlite")
df = pd.read_sql_query("SELECT * from Message", con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
#    MessageId  count      Time        Data  Satellites count  Pulse count  \
# 0          1      0      None        None             99216          NaN
# 1          2      1      None        None             99145          NaN
# 2          3      2      None        None             99148          NaN
# 3          4      3      None        None             99150          NaN
# 4          5      4  06:32:52  2024-07-06             99160          NaN
#
#    Seconds from start  Angel speed x  Angel speed y  Angel speed z  ...  \
# 0                 NaN            0.0            0.0            0.0  ...
# 1                 NaN            0.0            0.0            0.0  ...
# 2                 NaN            0.0            0.0            0.0  ...
# 3                 NaN            0.0            0.0            0.0  ...
# 4                 NaN            0.0            0.0            0.0  ...
#
#    Pressure  Compass x  Compass y  Compass z  GPS Altitude  Latitude  \
# ...

# %%
df.head()
# Out:
#    MessageId  count      Time        Data  Satellites count  Pulse count  \
# 0          1      0      None        None             99216          NaN
# 1          2      1      None        None             99145          NaN
# 2          3      2      None        None             99148          NaN
# 3          4      3      None        None             99150          NaN
# 4          5      4  06:32:52  2024-07-06             99160          NaN
#
#    Seconds from start  Angel speed x  Angel speed y  Angel speed z  ...  \
# 0                 NaN            0.0            0.0            0.0  ...
# 1                 NaN            0.0            0.0            0.0  ...
# 2                 NaN            0.0            0.0            0.0  ...
# 3                 NaN            0.0            0.0            0.0  ...
# 4                 NaN            0.0            0.0            0.0  ...
#
#    Pressure  Compass x  Compass y  Compass z  GPS Altitude  Latitude  \
# ...

# %%
# profile = ProfileReport(df, title="Profiling Report", correlations = {
#     "pearson": {"calculate": True},
#     "spearman": {"calculate": True},
#     "kendall": {"calculate": True},
#     "cramers": {"calculate": True},
#     "phi_k": {"calculate": True},
#   })
# profile.to_notebook_iframe()

# %%
df
# Out:
#       MessageId  count      Time        Data  Satellites count  Pulse count  \
# 0             1      0      None        None             99216          NaN
# 1             2      1      None        None             99145          NaN
# 2             3      2      None        None             99148          NaN
# 3             4      3      None        None             99150          NaN
# 4             5      4  06:32:52  2024-07-06             99160          NaN
# ...         ...    ...       ...         ...               ...          ...
# 1356       1357   1356  07:33:14  2024-07-06             66387         12.0
# 1357       1358   1357  07:33:17  2024-07-06             65253          5.0
# 1358       1359   1358  07:33:20  2024-07-06             68259          8.0
# 1359       1360   1359  07:33:22  2024-07-06             68390          2.0
# 1360       1361   1360  07:33:25  2024-07-06             68451          5.0
#
# ...

# %%
filtered_df = df.loc[(df['Time'] >= '07:00:00')]

# %%
# profile = ProfileReport(filtered_df, title="Profiling Report", correlations = {
#     "pearson": {"calculate": True},
#     "spearman": {"calculate": True},
#     "kendall": {"calculate": True},
#     "cramers": {"calculate": True},
#     "phi_k": {"calculate": True},
#   })
# profile.to_notebook_iframe()

# %%
plt.figure(figsize=(16, 8)) 
# plt.plot(filtered_df['Seconds from start'],filtered_df['Temp bat'])
plt.plot(df['Seconds from start'],df['Pulse count'])
# plt.title('График температуры батареи')
# plt.xlabel('Время со старта, секунды')
# plt.ylabel('Температура, °С')
# plt.xticks(range(1375, 3400, 125))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
